# %%
pip install keras-tcn
# Out:
# Collecting keras-tcn
#   Downloading keras_tcn-3.5.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras-tcn) (2.0.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (from keras-tcn) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (1.81.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->keras-tcn) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->keras-tcn) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->keras-tcn) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow->keras-tcn) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (2026.5.20)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->keras-tcn) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->keras-tcn) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow->keras-tcn) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow->keras-tcn) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow->keras-tcn) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow->keras-tcn) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow->keras-tcn) (0.1.2)
# Downloading keras_tcn-3.5.6-py3-none-any.whl (12 kB)
# Installing collected packages: keras-tcn
# Successfully installed keras-tcn-3.5.6

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tcn import TCN

# Load Dataset
df = pd.read_csv("continuous dataset.csv")

# Select Target
data = df[['nat_demand']]

# Normalize
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# Create Sequences
X = []
y = []

window_size = 24

for i in range(window_size, len(scaled_data)):
    X.append(scaled_data[i-window_size:i])
    y.append(scaled_data[i])

X = np.array(X)
y = np.array(y)

# Train Test Split
split = int(0.8 * len(X))

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# Build TCN Model
model = Sequential()

model.add(
    TCN(
        nb_filters=64,
        kernel_size=3,
        dilations=[1, 2, 4, 8],
        input_shape=(X_train.shape[1], X_train.shape[2])
    )
)

model.add(Dense(32, activation='relu'))
model.add(Dense(1))

model.compile(
    optimizer='adam',
    loss='mse'
)

model.summary()

# Train
model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.1
)

# Predict
pred = model.predict(X_test)

# Evaluation
rmse = np.sqrt(mean_squared_error(y_test, pred))
mae = mean_absolute_error(y_test, pred)

print("RMSE =", rmse)
print("MAE =", mae)
# Out:
# /usr/local/lib/python3.12/dist-packages/tcn/tcn.py:268: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super(TCN, self).__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ tcn (TCN)                       │ (None, 64)             │        86,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 88,961 (347.50 KB)
#  Trainable params: 88,961 (347.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 33s 47ms/step - loss: 0.1917 - val_loss: 8.0526e-04
# Epoch 2/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 25s 46ms/step - loss: 6.6092e-04 - val_loss: 5.9489e-04
# Epoch 3/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 25s 45ms/step - loss: 5.0451e-04 - val_loss: 6.3486e-04
# Epoch 4/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 25s 46ms/step - loss: 4.4488e-04 - val_loss: 6.2077e-04
# Epoch 5/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 25s 46ms/step - loss: 6.7132e-04 - val_loss: 3.9012e-04
# Epoch 6/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - loss: 6.3681e-04 - val_loss: 4.1267e-04
# Epoch 7/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 25s 46ms/step - loss: 5.5818e-04 - val_loss: 0.0014
# Epoch 8/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 25s 46ms/step - loss: 6.2662e-04 - val_loss: 3.9492e-04
# Epoch 9/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - loss: 4.9232e-04 - val_loss: 9.5900e-04
# Epoch 10/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 41s 45ms/step - loss: 5.5837e-04 - val_loss: 8.3994e-04
# Epoch 11/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - loss: 4.3084e-04 - val_loss: 6.8216e-04
# Epoch 12/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - loss: 4.1667e-04 - val_loss: 2.9183e-04
# Epoch 13/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 25s 45ms/step - loss: 5.3236e-04 - val_loss: 4.2565e-04
# Epoch 14/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 25s 45ms/step - loss: 4.0943e-04 - val_loss: 4.7225e-04
# Epoch 15/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - loss: 3.7352e-04 - val_loss: 5.7158e-04
# Epoch 16/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - loss: 3.6951e-04 - val_loss: 4.4627e-04
# Epoch 17/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - loss: 2.9388e-04 - val_loss: 9.5231e-04
# Epoch 18/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 42s 46ms/step - loss: 3.7383e-04 - val_loss: 3.6167e-04
# Epoch 19/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 25s 46ms/step - loss: 3.3998e-04 - val_loss: 9.0782e-04
# Epoch 20/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 24s 44ms/step - loss: 3.3765e-04 - val_loss: 3.5309e-04
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# RMSE = 0.01683662329360436
# MAE = 0.012301993799372652
