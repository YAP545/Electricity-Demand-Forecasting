# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Load Dataset
df = pd.read_csv("continuous dataset.csv")

# Select Target
data = df[['nat_demand']]

# Normalize
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# Create Sequences
X = []
y = []

window_size = 24

for i in range(window_size, len(scaled_data)):
    X.append(scaled_data[i-window_size:i])
    y.append(scaled_data[i])

X = np.array(X)
y = np.array(y)

# Train Test Split
split = int(0.8 * len(X))

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# Build RNN Model
model = Sequential()

model.add(
    SimpleRNN(
        64,
        activation='tanh',
        input_shape=(X_train.shape[1], X_train.shape[2])
    )
)

model.add(Dense(32, activation='relu'))
model.add(Dense(1))

model.compile(
    optimizer='adam',
    loss='mse'
)

# Train
model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.1
)

# Predict
pred = model.predict(X_test)

# Evaluation
rmse = np.sqrt(mean_squared_error(y_test, pred))
mae = mean_absolute_error(y_test, pred)

print("RMSE =", rmse)
print("MAE =", mae)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0043 - val_loss: 9.3270e-04
# Epoch 2/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 7.0556e-04 - val_loss: 0.0010
# Epoch 3/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 5.9122e-04 - val_loss: 6.7607e-04
# Epoch 4/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.1233e-04 - val_loss: 5.4690e-04
# Epoch 5/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 4.6174e-04 - val_loss: 5.3256e-04
# Epoch 6/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 4.3479e-04 - val_loss: 4.9943e-04
# Epoch 7/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.7502e-04 - val_loss: 4.6616e-04
# Epoch 8/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.3262e-04 - val_loss: 3.4108e-04
# Epoch 9/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.0884e-04 - val_loss: 3.4915e-04
# Epoch 10/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3.1106e-04 - val_loss: 3.3136e-04
# Epoch 11/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3.0201e-04 - val_loss: 3.1166e-04
# Epoch 12/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2.8944e-04 - val_loss: 3.7724e-04
# Epoch 13/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.7022e-04 - val_loss: 3.5678e-04
# Epoch 14/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 2.6052e-04 - val_loss: 3.0724e-04
# Epoch 15/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.5605e-04 - val_loss: 3.5061e-04
# Epoch 16/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.4745e-04 - val_loss: 3.9962e-04
# Epoch 17/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.4957e-04 - val_loss: 2.9996e-04
# Epoch 18/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.4596e-04 - val_loss: 3.4012e-04
# Epoch 19/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 2.4406e-04 - val_loss: 3.5001e-04
# Epoch 20/20
# 541/541 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.4121e-04 - val_loss: 3.4723e-04
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RMSE = 0.01613548407525147
# MAE = 0.01211096075655705
